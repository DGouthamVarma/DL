# %%
import general_functions as gf

# %%
rand_image = gf.getRandomImage(150,180,(224,224,3))

# %%
rand_image
# Out:
# array([[[171, 162, 171],
#         [168, 174, 167],
#         [160, 169, 164],
#         ...,
#         [165, 164, 162],
#         [177, 152, 154],
#         [164, 162, 164]],
#
#        [[169, 156, 153],
#         [153, 173, 164],
#         [179, 152, 175],
#         ...,
#         [172, 162, 175],
#         [166, 153, 178],
#         [166, 171, 155]],
#
#        [[156, 178, 175],
#         [179, 157, 170],
#         [171, 156, 162],
#         ...,
#         [156, 170, 178],
#         [160, 165, 163],
#         [155, 168, 160]],
#
#        ...,
#
#        [[168, 162, 159],
#         [160, 150, 150],
#         [165, 168, 175],
#         ...,
#         [175, 150, 173],
#         [167, 172, 167],
#         [178, 161, 167]],
#
#        [[170, 176, 154],
#         [159, 170, 170],
#         [153, 156, 156],
#         ...,
#         [173, 177, 164],
#         [171, 178, 175],
#         [168, 166, 176]],
#
#        [[159, 163, 170],
#         [171, 153, 170],
#         [165, 161, 157],
# ...

# %%
from PIL import Image

# %%
image = Image.open('bird.jpg')

# %%
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x426 at 0x7F7E34EFA320>

# %%
import numpy as np

# %%
np_image = np.uint8(image)

# %%
np_image
# Out:
# array([[[123, 160, 179],
#         [123, 160, 179],
#         [125, 160, 182],
#         ...,
#         [137, 179, 203],
#         [136, 176, 201],
#         [135, 175, 200]],
#
#        [[126, 161, 180],
#         [126, 161, 181],
#         [127, 162, 182],
#         ...,
#         [139, 181, 205],
#         [138, 180, 204],
#         [138, 178, 203]],
#
#        [[127, 162, 181],
#         [128, 163, 183],
#         [129, 164, 184],
#         ...,
#         [140, 182, 206],
#         [139, 181, 205],
#         [139, 181, 205]],
#
#        ...,
#
#        [[112, 103, 108],
#         [106, 102, 103],
#         [101, 101,  99],
#         ...,
#         [107, 123, 120],
#         [112, 131, 137],
#         [125, 144, 158]],
#
#        [[101,  99, 102],
#         [103,  98, 102],
#         [102,  93,  96],
#         ...,
#         [ 98, 113, 120],
#         [114, 128, 137],
#         [121, 138, 154]],
#
#        [[ 96,  94,  97],
#         [ 97,  92,  96],
#         [ 97,  88,  91],
# ...

# %%
rand_image = gf.getRandomImage(150, 180,(3,224,224))

# %%
rand_image
# Out:
# tensor([[[172., 163., 154.,  ..., 166., 178., 167.],
#          [152., 153., 170.,  ..., 176., 162., 168.],
#          [166., 173., 176.,  ..., 165., 158., 167.],
#          ...,
#          [155., 159., 154.,  ..., 152., 164., 172.],
#          [162., 157., 172.,  ..., 175., 154., 158.],
#          [170., 162., 177.,  ..., 166., 168., 169.]],
#
#         [[163., 163., 176.,  ..., 165., 154., 164.],
#          [179., 168., 165.,  ..., 166., 155., 173.],
#          [154., 162., 166.,  ..., 171., 155., 162.],
#          ...,
#          [163., 158., 152.,  ..., 150., 170., 161.],
#          [160., 174., 179.,  ..., 151., 171., 178.],
#          [171., 156., 175.,  ..., 166., 170., 155.]],
#
#         [[172., 161., 164.,  ..., 162., 176., 172.],
#          [162., 150., 172.,  ..., 175., 173., 156.],
#          [155., 170., 176.,  ..., 165., 168., 159.],
#          ...,
#          [172., 175., 173.,  ..., 162., 169., 176.],
#          [163., 159., 179.,  ..., 153., 170., 168.],
# ...

# %%
rand_image.shape
# Out:
# torch.Size([3, 224, 224])

# %%
processed_image = gf.preprocessImage(rand_image, True)

# %%
processed_image
# Out:
# tensor([[[[0.8276, 0.6734, 0.5193,  ..., 0.7248, 0.9303, 0.7419],
#           [0.4851, 0.5022, 0.7933,  ..., 0.8961, 0.6563, 0.7591],
#           [0.7248, 0.8447, 0.8961,  ..., 0.7077, 0.5878, 0.7419],
#           ...,
#           [0.5364, 0.6049, 0.5193,  ..., 0.4851, 0.6906, 0.8276],
#           [0.6563, 0.5707, 0.8276,  ..., 0.8789, 0.5193, 0.5878],
#           [0.7933, 0.6563, 0.9132,  ..., 0.7248, 0.7591, 0.7762]],
#
#          [[0.8179, 0.8179, 1.0455,  ..., 0.8529, 0.6604, 0.8354],
#           [1.0980, 0.9055, 0.8529,  ..., 0.8704, 0.6779, 0.9930],
#           [0.6604, 0.8004, 0.8704,  ..., 0.9580, 0.6779, 0.8004],
#           ...,
#           [0.8179, 0.7304, 0.6254,  ..., 0.5903, 0.9405, 0.7829],
#           [0.7654, 1.0105, 1.0980,  ..., 0.6078, 0.9580, 1.0805],
#           [0.9580, 0.6954, 1.0280,  ..., 0.8704, 0.9405, 0.6779]],
#
#          [[1.1934, 1.0017, 1.0539,  ..., 1.0191, 1.2631, 1.1934],
#           [1.0191, 0.8099, 1.1934,  ..., 1.2457, 1.2108, 0.9145],
# ...
